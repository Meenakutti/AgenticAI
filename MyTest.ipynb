# %% [markdown]
# <a href="https://colab.research.google.com/github/Meenakutti/AgenticAI/blob/AgenticAI-Assignments/MyTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openai import OpenAI
from google.colab import userdata

client = OpenAI(api_key=userdata.get('MyOpenAI_APIKey'))

response = client.responses.create(
  model="gpt-5-nano",
  input="write a haiku about ai",
  store=True,
)

print(response.output_text);
# Out:
# Silicon minds hum
# quiet code threads dream in dark
# grows with human hands
